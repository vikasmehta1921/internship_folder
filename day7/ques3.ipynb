# %%
import pandas as pd

# %%
data={
    "Name":["Vikas","Vivek","Nikhil"],
    "Marks":[80,90,70]
}

df=pd.DataFrame(data)

print(df)
# Out:
#      Name  Marks
# 0   Vikas     80
# 1   Vivek     90
# 2  Nikhil     70

# %%
print(df.iloc[1])
# Out:
# Name     Vivek
# Marks       90
# Name: 1, dtype: object

# %%
print(df.iloc[1])
# Out:
# Name     Vivek
# Marks       90
# Name: 1, dtype: object

# %%
print(df[df["Marks"]>75])
# Out:
#     Name  Marks
# 0  Vikas     80
# 1  Vivek     90

# %%
new_row={
    "Name":"Vikram",
    "Marks":95
}

df.loc[3]=new_row

print(df)
# Out:
#      Name  Marks
# 0   Vikas     80
# 1   Vivek     90
# 2  Nikhil     70
# 3  Vikram     95

# %%
rows=df.values.tolist()

print(rows)
# Out:
# [['Vikas', 80], ['Vivek', 90], ['Nikhil', 70], ['Vikram', 95]]
